# %%
import nltk
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

nltk.download('punkt')
nltk.download("stopwords")
nltk.download('wordnet')
os.chdir("../")
# Out:
# [nltk_data] Downloading package wordnet to /home/wk3user3/nltk_data...
# True

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("data/processed/counsel-chat-best-answer.csv")
df.head()
# Out:
#    questionID                                      questionTitle  \
# 0           0          Do I have too many issues for counseling?
# 1           1  My apartment manager won't let me keep an emot...
# 2           2           I feel like my mother doesn't support me
# 3           3        Why do I feel like I don't belong anywhere?
# 4           4                      How can I help my girlfriend?
#
#                                         questionText       topic  \
# 0  I have so many issues to address. I have a his...  depression
# 1  I have been diagnosed with general anxiety and...  depression
# 2  My mother is combative with me when I say I do...  depression
# 3  There are many people willing to lovingly prov...  depression
# 4  My girlfriend just quit drinking and she becam...  depression
#
#                                           answerText  upvotes  views
# 0  It is very common for people to have multiple ...        3   1971
# 1  This can be a difficult situation.  Typically,...        2   1026
# 2  Do you live with your mom and have constant in...        2    187
# 3  I truly understand what you are saying. I want...        1     62
# 4  You're probably not going to like my answer.Yo...        3    824

# %%
topics = [
    topic 
    for topic, count in df.groupby("topic").count()["questionText"].to_dict().items()
    if count > 20
]
topics
# Out:
# ['anxiety',
#  'depression',
#  'family-conflict',
#  'intimacy',
#  'parenting',
#  'relationship-dissolution',
#  'relationships',
#  'self-esteem']

# %% [markdown]
# ### Pre-process data

# %%
def process_text(text):
    
    # convert to lower case
    text = text.lower()
    
    # remove punctuations
    text = re.sub(r"(\W|_)+", " ", text)
    
    # remove stopwords
    for stopword in stopwords.words("english"):
        text = re.sub(r"\s" + stopword + r"\s", " ", " " + text)
    
    return text.strip()

# %%
def lemmatization(text):
    lemmatizer = WordNetLemmatizer()
    text = " ".join([
        lemmatizer.lemmatize(word) for word in word_tokenize(text)
    ])
    return text

# %%
df["questionTextProcessed"] = df["questionText"].apply(process_text)
df["questionTextLemm"] = df["questionTextProcessed"].apply(lemmatization)
df[["questionText", "questionTextProcessed", "questionTextLemm"]].head()
# Out:
#                                         questionText  \
# 0  I have so many issues to address. I have a his...
# 1  I have been diagnosed with general anxiety and...
# 2  My mother is combative with me when I say I do...
# 3  There are many people willing to lovingly prov...
# 4  My girlfriend just quit drinking and she becam...
#
#                                questionTextProcessed  \
# 0  many issues address history sexual abuse breas...
# 1  diagnosed general anxiety depression family do...
# 2  mother combative say want talk depression supp...
# 3  many people willing lovingly provide home food...
# 4  girlfriend quit drinking became really depress...
#
#                                     questionTextLemm
# 0  many issue address history sexual abuse breast...
# 1  diagnosed general anxiety depression family do...
# 2  mother combative say want talk depression supp...
# 3  many people willing lovingly provide home food...
# 4  girlfriend quit drinking became really depress...

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("corpora")
# Out:
# 'corpus'

# %% [markdown]
# ### Generate wordcloud

# %%
fig = plt.figure(figsize=(8, 12))
for i, topic in enumerate(topics):
    fig.add_subplot(4, 2, i+1)
    texts = df[df.topic == topic]["questionTextLemm"]
    wordcloud = WordCloud(background_color="white").generate(
        " ".join(texts)
    )
    plt.imshow(wordcloud)
    plt.title(topic)
    plt.axis("off")
plt.show()
